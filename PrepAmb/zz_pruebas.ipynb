# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `extl_raw`
URL 'abfss://raw@adlsbsriskdev.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `cred-sbsrisk-dev`);

CREATE EXTERNAL LOCATION IF NOT EXISTS `extl_bronze`
URL 'abfss://bronze@adlsbsriskdev.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `cred-sbsrisk-dev`);

CREATE EXTERNAL LOCATION IF NOT EXISTS `extl_silver`
URL 'abfss://silver@adlsbsriskdev.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `cred-sbsrisk-dev`);

CREATE EXTERNAL LOCATION IF NOT EXISTS `extl_gold`
URL 'abfss://gold@adlsbsriskdev.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `cred-sbsrisk-dev`);

# %%
# %sql
SHOW EXTERNAL LOCATIONS;

# %%
# %sql
CREATE CATALOG IF NOT EXISTS sbsrisk_dev;

CREATE SCHEMA IF NOT EXISTS sbsrisk_dev.bronze
MANAGED LOCATION 'abfss://bronze@adlsbsriskdev.dfs.core.windows.net/';

CREATE SCHEMA IF NOT EXISTS sbsrisk_dev.silver
MANAGED LOCATION 'abfss://silver@adlsbsriskdev.dfs.core.windows.net/';

CREATE SCHEMA IF NOT EXISTS sbsrisk_dev.gold
MANAGED LOCATION 'abfss://gold@adlsbsriskdev.dfs.core.windows.net/';

# %%
# %sql
CREATE CATALOG IF NOT EXISTS sbsrisk_dev
MANAGED LOCATION 'abfss://metastore@adlsbsriskdev.dfs.core.windows.net/sbsrisk_dev/';

# %%
# %sql DESCRIBE SCHEMA EXTENDED sbsrisk_dev.bronze

# %% [markdown]
# # 2. Validación de Unity Catalog

# %%
# %sql SHOW STORAGE CREDENTIALS;

# %%
# %sql
SHOW CATALOGS;
SHOW SCHEMAS IN sbsrisk_dev;
SHOW EXTERNAL LOCATIONS;

# %%
# %sql
DESCRIBE SCHEMA EXTENDED sbsrisk_dev.bronze;
DESCRIBE SCHEMA EXTENDED sbsrisk_dev.silver;
DESCRIBE SCHEMA EXTENDED sbsrisk_dev.gold;

# %%
spark.sql("SHOW CATALOGS").show(truncate=False)

# %%
spark.sql("SHOW SCHEMAS IN sbsrisk_dev").show(truncate=False)

# %%
display(dbutils.fs.ls("abfss://raw@adlsbsriskdev.dfs.core.windows.net/"))
display(dbutils.fs.ls("abfss://bronze@adlsbsriskdev.dfs.core.windows.net/"))
display(dbutils.fs.ls("abfss://silver@adlsbsriskdev.dfs.core.windows.net/"))
display(dbutils.fs.ls("abfss://gold@adlsbsriskdev.dfs.core.windows.net/"))

# %%
# %sql
SHOW CATALOGS;
SHOW SCHEMAS IN sbsrisk_dev;

# %%
# %sql
CREATE CATALOG IF NOT EXISTS sbsrisk_dev
MANAGED LOCATION 'abfss://metastore@adlsbsriskdev.dfs.core.windows.net/sbsrisk_dev/';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS sbsrisk_dev.bronze
MANAGED LOCATION 'abfss://bronze@adlsbsriskdev.dfs.core.windows.net/sbsrisk_dev/';

CREATE SCHEMA IF NOT EXISTS sbsrisk_dev.silver
MANAGED LOCATION 'abfss://silver@adlsbsriskdev.dfs.core.windows.net/sbsrisk_dev/';

CREATE SCHEMA IF NOT EXISTS sbsrisk_dev.gold
MANAGED LOCATION 'abfss://gold@adlsbsriskdev.dfs.core.windows.net/sbsrisk_dev/';

# %%
# %sql
DESCRIBE SCHEMA EXTENDED sbsrisk_dev.bronze;
DESCRIBE SCHEMA EXTENDED sbsrisk_dev.silver;
DESCRIBE SCHEMA EXTENDED sbsrisk_dev.gold;
