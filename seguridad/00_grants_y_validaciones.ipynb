# %%
# %sql
-- Ajusta el grupo/usuario según tu caso real
-- Si no puedes crear grupo en tu entorno, deja solo los GRANT a `account users`.

--'dataengineer_adbpf@hotmail.com';
--'dataengineer_adbpf_hotmail.com#EXT#@dataengineeradbpfhotmail.onmicrosoft.com';

USE CATALOG sbsrisk_dev;

-- Permisos mínimos para consumir
GRANT USE CATALOG ON CATALOG sbsrisk_dev TO `account users`;
GRANT USE SCHEMA ON SCHEMA sbsrisk_dev.gold TO `account users`;

-- Select sobre tablas GOLD (mínimo)
GRANT SELECT ON TABLE sbsrisk_dev.gold.gold_morosidad_tipo_pivot TO `account users`;
GRANT SELECT ON TABLE sbsrisk_dev.gold.gold_morosidad_tipo_ranking TO `account users`;
GRANT SELECT ON TABLE sbsrisk_dev.gold.gold_morosidad_tipo_timeseries TO `account users`;

-- (Opcional) también silver
GRANT USE SCHEMA ON SCHEMA sbsrisk_dev.silver TO `account users`;
GRANT SELECT ON TABLE sbsrisk_dev.silver.silver_morosidad_dias_wide TO `account users`;
GRANT SELECT ON TABLE sbsrisk_dev.silver.silver_morosidad_tipo_long TO `account users`;
