# %%
# %sql
-- DROPS en orden: GOLD -> SILVER -> BRONZE
DROP TABLE IF EXISTS sbsrisk_dev.gold.gold_morosidad_tipo_pivot;
DROP TABLE IF EXISTS sbsrisk_dev.gold.gold_morosidad_tipo_ranking;
DROP TABLE IF EXISTS sbsrisk_dev.gold.gold_morosidad_tipo_timeseries;

DROP TABLE IF EXISTS sbsrisk_dev.silver.silver_morosidad_dias_wide;
DROP TABLE IF EXISTS sbsrisk_dev.silver.silver_morosidad_tipo_long;

DROP TABLE IF EXISTS sbsrisk_dev.bronze.bronze_sbs_morosidad_2024;
DROP TABLE IF EXISTS sbsrisk_dev.bronze.bronze_sbs_morosidad_2025;
